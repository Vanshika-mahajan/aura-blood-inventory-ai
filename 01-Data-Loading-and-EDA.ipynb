# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F248-05BE
#
#  Directory of C:\Users\91628\Documents\Aura\aura-blood-inventory-ai
#
# 12-08-2025  15:38    <DIR>          .
# 12-08-2025  15:38    <DIR>          ..
# 12-08-2025  14:34             4,895 .gitignore
# 12-08-2025  15:24    <DIR>          .ipynb_checkpoints
# 12-08-2025  15:38            18,579 01-Data-Loading-and-EDA.ipynb
# 12-08-2025  14:34             1,094 LICENSE
# 12-08-2025  14:34               122 README.md
# 22-05-2023  22:23            12,843 transfusion.csv
# 22-05-2023  22:23             3,165 transfusion.names
#                6 File(s)         40,698 bytes
#                3 Dir(s)   1,519,165,440 bytes free

# %%
filename='transfusion.csv'

# %%
df_uci=pd.read_csv(filename)

# %%
df_uci.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
# 1                 0                 13                   3250             28
# 2                 1                 16                   4000             35
# 3                 2                 20                   5000             45
# 4                 1                 24                   6000             77
#
#    whether he/she donated blood in March 2007
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           0

# %%
df_uci.columns=['recency_months', 
    'frequency_times', 
    'monetary_cc_blood', 
    'time_months', 
    'donated_mar_2007']

# %%
df_uci.head()
# Out:
#    recency_months  frequency_times  monetary_cc_blood  time_months  \
# 0               2               50              12500           98
# 1               0               13               3250           28
# 2               1               16               4000           35
# 3               2               20               5000           45
# 4               1               24               6000           77
#
#    donated_mar_2007
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 0
